# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5 # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.2-198-gacff977 Python-3.7.15 torch-1.12.1+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.4/107.7 GB disk)

# %%
from glob import glob

img_list = glob('/content/drive/MyDrive/Yolov5/detection_project/datasets/train/images/*')
val_img_list = glob('/content/drive/MyDrive/Yolov5/detection_project/datasets/val/images/*') 
test_img_list = glob('/content/drive/MyDrive/Yolov5/detection_project/datasets/test/images/*')

# %%
with open('/content/drive/MyDrive/Yolov5/detection_project/datasets/train.txt', 'w') as f:
    f.write('\n'.join(img_list) + '\n')

# %%
with open('/content/drive/MyDrive/Yolov5/detection_project/datasets/val.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
with open('/content/drive/MyDrive/Yolov5/detection_project/datasets/test.txt', 'w') as f:
    f.write('\n'.join(test_img_list) + '\n')

# %%
import yaml

with open("/content/yolov5/data/coco.yaml", 'r') as f:
  data = yaml.load(f, Loader=yaml.FullLoader)

# %%
# !cp /content/yolov5/data/coco.yaml /content/yolov5/data/my_data.yaml

# %%
import yaml

with open("/content/yolov5/data/my_data.yaml", 'r') as f:
  data = yaml.load(f, Loader=yaml.FullLoader)
data['path'] = "/datasets"
data['train'] = "/content/drive/MyDrive/Yolov5/detection_project/datasets/train.txt"
data['val'] = "/content/drive/MyDrive/Yolov5/detection_project/datasets/val.txt"
data['test'] = "/content/drive/MyDrive/Yolov5/detection_project/datasets/test.txt"
data['names'] = {0: 'fire', 1:'smoke', 2:'car', 3:'big car'}
with open("/content/yolov5/data/my_data.yaml", 'w') as f:
  yaml.dump(data, f)

# %%
# !cp /content/drive/MyDrive/Yolov5/detection_project/my_yolo.yaml /content/yolov5/models/my_yolo.yaml

# %%
# !python train.py --data my_data.yaml --cfg my_yolo.yaml --weights '' --batch-size 64
# Out:
# train: weights=, cfg=my_yolo.yaml, data=my_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-195-gdf80e7c Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !cp -r /content/yolov5/runs/train/exp /content/drive/MyDrive/Yolov5/exp_1
